# %% [markdown]
# <a href="https://colab.research.google.com/github/mehravehj/Debiased_supernet_sampling/blob/main/Training_progress_pooling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Trarining uniformly for Pooling search space**
# record checkpoints when training

# %%
import pandas as pd
from google.colab import drive

# Mount your Google Drive
drive.mount('/content/drive', force_remount=True)
# prompt: read supernet_chpt_epoch_0.t7
# Out:
# Mounted at /content/drive

# %% [markdown]
# Definitions

# %%
# Block 1: All Definitions (Complete with modified ResNet20)

import os
import math
import random # For shuffle in data_loader
from datetime import datetime
from itertools import combinations
from typing import Optional, Tuple, List, Dict, Union, Type # Added Type for block_type hint

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.optim.lr_scheduler import _LRScheduler
from torch.utils.data import DataLoader
from torch.utils.data.sampler import SubsetRandomSampler
import torchvision
import torchvision.transforms as transforms
from torch.distributions.categorical import Categorical


# --- From utility_functions.py ---
def string_to_list(x: str, leng: int) -> List[int]:
    """
    Converts a string to a list of integers.
    If 'x' is a comma-separated string of numbers, it splits them.
    The resulting list must have a length equal to 'leng'.
    If 'x' is a single number, it creates a list of 'leng' repetitions of that number.
    """
    if not isinstance(x, str):
        raise TypeError(f"Input 'x' must be a string, got {type(x)}")
    if not isinstance(leng, int) or leng <= 0:
        raise ValueError(f"'leng' must be a positive integer, got {leng}")

    if ',' in x:
        parts = x.split(',')
        try:
            res = [int(p.strip()) for p in parts]
        except ValueError as e:
            raise ValueError(f"Invalid number in comma-separated string '{x}': {e}")
        if len(res) != leng:
            raise ValueError(f"Channel string '{x}' provides {len(res)} values, but network depth 'leng' is {leng}. They must match.")
    else:
        try:
            val = int(x.strip())
            res = [val for _ in range(leng)]
        except ValueError:
            raise ValueError(f"Channel string '{x}' is not a valid single integer or a comma-separated list of integers.")
    return res

# --- From search_space_design.py ---
def create_search_space(num_layers: int, num_scales: int) -> Tuple[tuple, int]:
    if num_layers < 0: # Allow num_layers = 0 for empty search space
        raise ValueError("num_layers cannot be negative.")
    if num_scales <= 0:
        raise ValueError("num_scales must be positive.")

    if num_layers == 0:
        print(f'No layers defined (num_layers=0), 0 paths created.')
        return tuple(), 0

    # num_scales > num_layers implies more pooling stages than layers (after the first conv) to put them after.
    if num_scales > num_layers :
         raise ValueError(f"num_scales ({num_scales}) cannot exceed num_layers ({num_layers}) for this search space design when num_layers > 0.")

    num_pooling = num_scales - 1
    # num_available_positions_for_pooling refers to the number of positions *after* the initial conv block
    # and after each subsequent ResBasicBlock where a pooling operation could be inserted.
    # If path has length num_layers, and path[0] is before first block (always 0 pool),
    # then there are num_layers-1 subsequent positions for pooling.
    num_available_positions_for_pooling = num_layers - 1

    if num_pooling < 0 : # Should not happen if num_scales is positive
        num_pooling = 0 # Corrects to no pooling if num_scales = 0 somehow (though arg check prevents)

    # This condition checks if we're trying to place more pooling layers than available slots
    if num_pooling > 0 and num_available_positions_for_pooling < num_pooling :
        raise ValueError(
            f"Cannot place {num_pooling} pooling layers in {num_available_positions_for_pooling} available slots "
            f"(num_layers={num_layers}, num_scales={num_scales})."
        )

    paths = []
    # combinations(range(N), k)
    # N = num_available_positions_for_pooling
    # k = num_pooling
    # if N=0 (num_layers=1), k=0 (num_scales=1) => combinations(range(0),0) gives one empty tuple. p=[]. path=[0]. Correct.
    # if N=0 (num_layers=1), k>0 (num_scales>1) => combinations(range(0),k) gives zero items. paths list remains empty. Correct.

    for positions in combinations(range(num_available_positions_for_pooling), num_pooling):
        p = [0] * num_available_positions_for_pooling
        for i in positions:
            p[i] = 1
        paths.append(tuple([0] + p)) # path[0] is always 0 (no pooling before the first block)

    paths_tuple = tuple(paths)
    number_paths = len(paths_tuple)

    # This specific check handles the case where num_layers=1, num_scales>1 leading to 0 paths
    if number_paths == 0 and num_layers > 0:
        if not (num_available_positions_for_pooling == 0 and num_pooling > 0):
             # If it's not the expected C(0, k>0) case, then it's an unexpected empty path list
             print(f"Warning: No paths generated for num_layers={num_layers}, num_scales={num_scales}, "
                   f"num_pooling={num_pooling}, num_available_positions={num_available_positions_for_pooling}. "
                   f"This might be an issue if paths were expected.")

    print(f'All {number_paths} paths created.')
    if 0 < number_paths < 20: # Print paths only if a small number for brevity
        print(paths_tuple)
    return paths_tuple, number_paths


def init_path_logit(num_paths: int, initial_logits: float = 1.0) -> torch.Tensor:
    if num_paths < 0:
        raise ValueError("Number of paths cannot be negative.")
    if num_paths == 0:
        return torch.FloatTensor([])
    initial_path_weights = torch.FloatTensor([initial_logits for _ in range(num_paths)])
    return initial_path_weights

def sample_uniform(sample_weights: torch.Tensor, paths: tuple) -> Tuple[int, tuple]:
    if not paths:
        raise ValueError("Cannot sample from empty paths tuple.")
    if sample_weights.nelement() == 0:
        raise ValueError("Cannot sample path: sample_weights tensor is empty (likely num_paths was 0).")

    if sample_weights.dim() > 1:
        sample_weights = sample_weights.squeeze()
        if sample_weights.dim() > 1:
            raise ValueError("sample_weights must be a 1D tensor of logits.")
    if sample_weights.nelement() != len(paths):
        raise ValueError(f"Number of sample_weights ({sample_weights.nelement()}) must match number of paths ({len(paths)}).")

    try:
        prob_distribution = Categorical(logits=sample_weights)
    except RuntimeError as e:
        if not torch.isfinite(sample_weights).all():
            raise ValueError("Logits in sample_weights must be finite.") from e
        raise
    path_index = int(prob_distribution.sample().item())
    if not (0 <= path_index < len(paths)):
        raise IndexError(f"Sampled path_index {path_index} is out of bounds for paths list of length {len(paths)}.")
    return path_index, paths[path_index]


# --- From lr_scheduler.py ---
class CosineAnnealingWarmupRestarts(_LRScheduler):
    def __init__(self,
                 optimizer : torch.optim.Optimizer,
                 first_cycle_steps : int,
                 cycle_mult : float = 1.,
                 max_lr : float = 0.1,
                 min_lr : float = 0.001,
                 warmup_steps : int = 0,
                 gamma : float = 1.,
                 last_epoch : int = -1
        ):
        if not first_cycle_steps > 0:
            raise ValueError("first_cycle_steps must be positive.")
        if warmup_steps < 0:
            raise ValueError("warmup_steps cannot be negative.")
        if warmup_steps >= first_cycle_steps:
            raise ValueError("warmup_steps must be less than first_cycle_steps.")

        self.first_cycle_steps = first_cycle_steps
        self.cycle_mult = cycle_mult
        self.base_max_lr = max_lr
        self.max_lr = max_lr
        self.min_lr = min_lr
        self.warmup_steps = warmup_steps
        self.gamma = gamma
        self.cur_cycle_steps = first_cycle_steps
        self.cycle = 0
        self.step_in_cycle = last_epoch
        super(CosineAnnealingWarmupRestarts, self).__init__(optimizer, last_epoch)
        self.init_lr()

    def init_lr(self):
        self.base_lrs = []
        for param_group in self.optimizer.param_groups:
            param_group['lr'] = self.min_lr
            self.base_lrs.append(self.min_lr)

    def get_lr(self):
        if self.step_in_cycle == -1:
            return self.base_lrs
        elif self.step_in_cycle < self.warmup_steps:
            if self.warmup_steps == 0: # Avoid division by zero if no warmup
                 return [self.max_lr for _ in self.base_lrs]
            return [(self.max_lr - base_lr)*self.step_in_cycle / self.warmup_steps + base_lr for base_lr in self.base_lrs]
        else:
            denominator = (self.cur_cycle_steps - self.warmup_steps)
            if denominator <= 0: # Should be > 0 if cur_cycle_steps > warmup_steps
                 return [self.min_lr for _ in self.base_lrs] # Or max_lr if cycle just ended? min_lr seems safer for cosine end.
            return [base_lr + (self.max_lr - base_lr) *
                    (1 + math.cos(math.pi * (self.step_in_cycle - self.warmup_steps) / denominator)) / 2
                    for base_lr in self.base_lrs]

    def step(self, epoch: Optional[int] = None):
        if epoch is None:
            epoch = self.last_epoch + 1
            self.step_in_cycle = self.step_in_cycle + 1
            if self.step_in_cycle >= self.cur_cycle_steps:
                self.cycle += 1
                self.step_in_cycle = self.step_in_cycle - self.cur_cycle_steps
                self.cur_cycle_steps = int((self.cur_cycle_steps - self.warmup_steps) * self.cycle_mult) + self.warmup_steps
        else:
            if epoch >= self.first_cycle_steps:
                if self.cycle_mult == 1.:
                    self.step_in_cycle = epoch % self.first_cycle_steps
                    self.cycle = epoch // self.first_cycle_steps
                else:
                    if self.cycle_mult <= 1.0: # Non-increasing cycle length
                        print(f"Warning: CosineAnnealingWarmupRestarts encountered cycle_mult={self.cycle_mult} <= 1.0. Using simpler cycle calculation.")
                        self.cycle = epoch // self.first_cycle_steps if self.first_cycle_steps > 0 else 0
                        self.step_in_cycle = epoch % self.first_cycle_steps if self.first_cycle_steps > 0 else epoch
                        self.cur_cycle_steps = self.first_cycle_steps
                    else: # Increasing cycle length
                        # Formula for sum of geometric series to find which cycle 'epoch' falls into
                        log_arg = (epoch / self.first_cycle_steps * (self.cycle_mult - 1) + 1) if self.first_cycle_steps > 0 else 1.0
                        if log_arg <= 0: # Should not happen with cycle_mult > 1 and epoch >= 0
                             print(f"Warning: CosineAnnealingWarmupRestarts encountered non-positive log argument: {log_arg}. Using simpler cycle calculation.")
                             self.cycle = epoch // self.first_cycle_steps if self.first_cycle_steps > 0 else 0
                             self.step_in_cycle = epoch % self.first_cycle_steps if self.first_cycle_steps > 0 else epoch
                             self.cur_cycle_steps = self.first_cycle_steps
                        else:
                            n = int(math.log(log_arg, self.cycle_mult))
                            self.cycle = n
                            # Sum of first n terms of geometric series: T_0 * (mult^n - 1) / (mult - 1)
                            denominator_cycle_sum = (self.cycle_mult - 1)
                            # if denominator_cycle_sum == 0: # Caught by cycle_mult == 1.
                            # sum_geometric_progression = self.first_cycle_steps * (self.cycle + 1)
                            # else:
                            sum_geometric_progression = self.first_cycle_steps * (self.cycle_mult**n - 1) / denominator_cycle_sum
                            self.step_in_cycle = epoch - int(sum_geometric_progression)
                            self.cur_cycle_steps = int(self.first_cycle_steps * self.cycle_mult**(n))
            else: # Before the first cycle completes
                self.cur_cycle_steps = self.first_cycle_steps
                self.step_in_cycle = epoch

        self.max_lr = self.base_max_lr * (self.gamma**self.cycle)
        self.last_epoch = math.floor(epoch)
        for param_group, lr_val in zip(self.optimizer.param_groups, self.get_lr()):
            param_group['lr'] = lr_val


# --- From create_model.py ---
def pooling_func(x: torch.Tensor) -> torch.Tensor:
    out = F.max_pool2d(x, kernel_size=2)
    return out

class ResBasicBlock(nn.Module):
    def __init__(self, in_planes: int, out_planes: int, stride: int = 1, downsample: Optional[nn.Module] = None):
        super(ResBasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, out_planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(out_planes, affine=False)#, track_running_stats=False)
        self.relu = nn.ReLU(inplace=True)
        self.conv2 = nn.Conv2d(out_planes, out_planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(out_planes, affine=False)#, track_running_stats=False)
        self.downsample = downsample

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        identity = x
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)
        out = self.conv2(out)
        out = self.bn2(out)
        if self.downsample is not None:
            identity = self.downsample(x)
        out += identity
        out = self.relu(out)
        return out

class BasicConvBlock(nn.Module):
    def __init__(self, in_planes: int, out_planes: int, kernel_size: int = 3):
        super(BasicConvBlock, self).__init__()
        self.conv = nn.Conv2d(in_planes, out_planes, kernel_size, stride=1, padding=kernel_size//2, bias=False)
        self.bn = nn.BatchNorm2d(out_planes, affine=False)#, track_running_stats=False)
        self.relu = nn.ReLU(inplace=True)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        out = self.conv(x)
        out = self.bn(out)
        out = self.relu(out)
        return out

class ResNet20(nn.Module): # MODIFIED CLASS
    def __init__(self, block_type: Type[ResBasicBlock], num_layers: int, channels: List[int], num_classes: int = 10):
        super(ResNet20, self).__init__()
        if num_layers <= 0:
            raise ValueError("num_layers must be positive.")
        if len(channels) != num_layers:
            raise ValueError(f"Length of 'channels' list ({len(channels)}) must match 'num_layers' ({num_layers}).")

        self.num_layers = num_layers
        layers_list = [BasicConvBlock(3, channels[0])] # Input channels for image is 3
        self.current_inplanes = channels[0] # Output of the first block

        for i in range(1, num_layers):
            layers_list.append(self._make_layer(block_type, channels[i]))
            # self.current_inplanes is updated to channels[i] inside _make_layer

        self.res_blocks = nn.ModuleList(layers_list)
        self.adaptive_avg_pool = nn.AdaptiveAvgPool2d((1, 1))
        self.fc = nn.Linear(self.current_inplanes, num_classes, bias=False) # Uses output channels of the last block

        self.path_pooling_config: Optional[Tuple[int, ...]] = None

    def _make_layer(self, block_type: Type[ResBasicBlock], planes: int, stride_for_block: int = 1) -> nn.Module:
        downsample_shortcut = None
        if self.current_inplanes != planes:
            downsample_shortcut = nn.Sequential(
                nn.Conv2d(self.current_inplanes, planes, kernel_size=1, stride=1, bias=False),
                nn.BatchNorm2d(planes, affine=False)#, track_running_stats=False),
            )
        layer = block_type(self.current_inplanes, planes, stride=stride_for_block, downsample=downsample_shortcut)
        self.current_inplanes = planes # Update for the next layer
        return layer

    def set_path(self, path: Tuple[int, ...]):
        if len(path) != self.num_layers:
            raise ValueError(f"Path length ({len(path)}) must match number of layers ({self.num_layers}).")
        self.path_pooling_config = path

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        if self.path_pooling_config is None:
            raise RuntimeError("Path not set. Call set_path(path) before forward pass.")

        out = x
        for c in range(self.num_layers):
            if self.path_pooling_config[c]:
                out = pooling_func(out)
            out = self.res_blocks[c](out)

        out = self.adaptive_avg_pool(out)
        out = out.view(out.size(0), -1)
        out = self.fc(out)
        return out

    def feature_extractor(self, x: torch.Tensor) -> List[torch.Tensor]:
        """
        Extracts feature maps from the network.
        Args:
            x (torch.Tensor): The input tensor.
        Returns:
            List[torch.Tensor]: A list of feature maps.
                                - Feature maps after each block in self.res_blocks.
                                - Feature map after self.adaptive_avg_pool.
        """
        if self.path_pooling_config is None:
            raise RuntimeError("Path not set. Call set_path(path) before calling feature_extractor.")

        feature_maps: List[torch.Tensor] = []
        out = x
        for c in range(self.num_layers):
            if self.path_pooling_config[c]:
                out = pooling_func(out)
            out = self.res_blocks[c](out)
            feature_maps.append(out)

        out = self.adaptive_avg_pool(out)
        feature_maps.append(out)
        return feature_maps


# --- From data_loader.py ---
def _data_transforms_cifar10() -> Tuple[transforms.Compose, transforms.Compose]:
    cifar_mean = [0.49139968, 0.48215827, 0.44653124]
    cifar_std = [0.24703233, 0.24348505, 0.26158768]
    train_transform = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize(cifar_mean, cifar_std),
    ])
    test_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize(cifar_mean, cifar_std),
    ])
    return train_transform, test_transform

def _validation_set_indices(total_train_samples: int, valid_percent: float) -> Tuple[List[int], List[int]]:
    if not (0.0 <= valid_percent < 1.0):
        raise ValueError("valid_percent must be between 0.0 and almost 1.0.")
    num_validation_samples = int(valid_percent * total_train_samples)
    num_train_samples = total_train_samples - num_validation_samples
    print(f'Total original training samples: {total_train_samples}')
    print(f'New training size: {num_train_samples}, Validation size: {num_validation_samples}')
    indexes = list(range(total_train_samples))
    random.shuffle(indexes)
    train_indices = indexes[:num_train_samples]
    val_indices = indexes[num_train_samples:]
    return train_indices, val_indices

def get_data_loaders(
    dataset_name: str,
    valid_percent: float,
    batch_size: int,
    dataset_dir: str = '~/data/', # Consider using os.path.expanduser for ~
    workers: int = 2
) -> Tuple[DataLoader, Optional[DataLoader], Tuple[List[int], List[int]]]:
    dataset_dir = os.path.expanduser(dataset_dir) # Added expanduser
    if dataset_name == 'CIFAR10':
        train_transform_CIFAR, test_transform_CIFAR = _data_transforms_cifar10()
        full_trainset = torchvision.datasets.CIFAR10(root=dataset_dir, train=True, download=True, transform=train_transform_CIFAR)
        # For validation, use the test transform (no augmentation) but on the training data split
        valset_for_loader = torchvision.datasets.CIFAR10(root=dataset_dir, train=True, download=True, transform=test_transform_CIFAR)
    else:
        raise Exception(f'Dataset {dataset_name} not supported!')

    total_train_samples = len(full_trainset)
    train_indices, val_indices = _validation_set_indices(total_train_samples, valid_percent)
    data_split_indices = (train_indices, val_indices)

    train_loader = DataLoader(full_trainset, batch_size=batch_size, sampler=SubsetRandomSampler(train_indices), num_workers=workers, pin_memory=True, drop_last=True)
    validation_loader = None
    if valid_percent > 0.0 and val_indices: # Ensure val_indices is not empty
        validation_loader = DataLoader(valset_for_loader, batch_size=batch_size, sampler=SubsetRandomSampler(val_indices), num_workers=workers, pin_memory=True, drop_last=False)
    return train_loader, validation_loader, data_split_indices


# --- From NAS_trainer.py (now ModelTrainer) ---
def create_single_model(layers: int, channels: List[int], num_classes: int = 10) -> nn.Module: # Added num_classes
    model = ResNet20(ResBasicBlock, layers, channels, num_classes=num_classes) # Pass num_classes
    return model

def create_optimizer_and_scheduler(
    sched_type: str,
    model: nn.Module,
    lr: float,
    momentum: float,
    weight_decay: float,
    epochs: int, # Total epochs for CosineAnnealingLR
    min_lr: float, # For schedulers
    first_cycle_steps: int, # For CosineAnnealingWarmupRestarts
    cycle_mult: float, # For CosineAnnealingWarmupRestarts
    warmup_steps: int, # For CosineAnnealingWarmupRestarts
    gamma: float # For CosineAnnealingWarmupRestarts
) -> Tuple[optim.Optimizer, Optional[_LRScheduler]]:
    optimizer = optim.SGD(model.parameters(), lr=lr, momentum=momentum, weight_decay=weight_decay)
    scheduler = None
    if sched_type == 'cosine_anneal':
        # epochs + 1 might be if T_max is total iterations, or if epochs is 0-indexed.
        # Usually T_max is the total number of epochs.
        scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs, eta_min=min_lr)
    elif sched_type == 'cosine_anneal_wr':
        scheduler = CosineAnnealingWarmupRestarts(optimizer, first_cycle_steps, cycle_mult, lr, min_lr, warmup_steps, gamma)
    elif sched_type == 'none' or sched_type is None:
        print("No learning rate scheduler will be used.")
    else:
        print(f"Warning: Unsupported scheduler type: '{sched_type}'. No scheduler will be used.")
    return optimizer, scheduler

def train_epoch_random_paths(
    model: nn.Module, # Should be ResNet20 instance
    train_queue: DataLoader,
    optimizer: optim.Optimizer,
    criterion: nn.Module,
    all_paths: tuple, # Tuple of path tuples
    uniform_path_weights: torch.Tensor, # Logits for sampling paths
    device: torch.device
) -> Tuple[float, float]: # Returns (average_loss, accuracy)
    model.train()
    total_loss = 0.0
    correct_predictions = 0
    total_samples = 0
    if len(train_queue) == 0:
        print("Warning: train_queue is empty. Skipping training for this epoch.")
        return 0.0, 0.0

    # Move weights to device once if they aren't already
    if uniform_path_weights.device != device:
        uniform_path_weights = uniform_path_weights.to(device)

    for inputs, targets in train_queue:
        inputs, targets = inputs.to(device), targets.to(device)

        _, current_path = sample_uniform(uniform_path_weights, all_paths) # sample_uniform expects weights, paths

        if not hasattr(model, 'set_path'):
            raise TypeError("Model does not have a 'set_path' method. Ensure it's the ResNet20 class.")
        model.set_path(current_path) # Type assertion for model if needed

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()
        _, predicted_classes = outputs.max(1)
        total_samples += targets.size(0)
        correct_predictions += predicted_classes.eq(targets).sum().item()

    avg_loss = total_loss / len(train_queue) if len(train_queue) > 0 else 0.0
    accuracy = (100. * correct_predictions / total_samples) if total_samples > 0 else 0.0
    # Consider printing epoch number if available
    print(f'Training Epoch: Avg Loss: {avg_loss:.4f}, Accuracy: {correct_predictions}/{total_samples} ({accuracy:.2f}%)')
    return avg_loss, accuracy

def validate_model_all_paths_on_batch(
    model: nn.Module, # Should be ResNet20 instance
    all_paths: tuple, # Tuple of path tuples
    val_inputs: torch.Tensor,
    val_targets: torch.Tensor,
    criterion: nn.Module,
    device: torch.device
) -> Tuple[Dict[str, torch.Tensor], Dict[str, Dict[str, Optional[torch.Tensor]]]]:
    model.eval()
    output_vectors_all_paths: Dict[str, torch.Tensor] = {}
    gradients_all_paths: Dict[str, Dict[str, Optional[torch.Tensor]]] = {}

    val_inputs, val_targets = val_inputs.to(device), val_targets.to(device)

    print(f"Starting validation for {len(all_paths)} paths on a single mini-batch...")
    if not all_paths:
        print("Warning: No paths provided for validation.")
        return output_vectors_all_paths, gradients_all_paths

    if not hasattr(model, 'set_path'):
        raise TypeError("Model does not have a 'set_path' method. Ensure it's the ResNet20 class.")

    for i, path_tuple in enumerate(all_paths):
        path_key = str(path_tuple)
        # print(f"  Validating path {i+1}/{len(all_paths)}: {path_tuple}") # Can be very verbose

        # Ensure model is zero_grad for each path's gradient calculation
        model.zero_grad()
        model.set_path(path_tuple)

        # Get output logits without gradients for storage
        with torch.no_grad():
            outputs_no_grad = model(val_inputs)
        output_vectors_all_paths[path_key] = outputs_no_grad.detach().cpu()

        # Re-enable grad for loss calculation and backward pass for this specific path
        # Detach inputs if they came from a previous computation graph part not relevant here
        outputs_for_loss = model(val_inputs.detach().clone()) # Use detached clone for clean grad calculation
        loss = criterion(outputs_for_loss, val_targets)
        loss.backward() # Accumulates gradients in model.parameters() for the current path

        current_path_gradients: Dict[str, Optional[torch.Tensor]] = {}
        for name, param in model.named_parameters():
            if param.grad is not None:
                current_path_gradients[name] = param.grad.clone().detach().cpu()
            else:
                # This case can happen if a parameter was not used in the forward pass for this specific path
                current_path_gradients[name] = None
        gradients_all_paths[path_key] = current_path_gradients

        # It's crucial to zero_grad() again if optimizer.step() is not called,
        # or before the next path's backward(). model.zero_grad() at start of loop handles this.

    print(f"Finished validation for all {len(all_paths)} paths.")
    return output_vectors_all_paths, gradients_all_paths

# %%
    # --- Manually Set Input Parameters Here ---
    config = {
        "dataset": "CIFAR10",
        "channels_string": "16,16,16,16,32,32,32,64,64,64", # Should match 'leng'
        "leng": 10,
        "batchsize": 512,
        "test_number": 3002,  # <--- YOUR INPUT TEST NUMBER (e.g., 1, 2, 3, ...)
        "seed": 3457,
        "epochs": 200,
        "validation_percent": 0.5, # Validation set is created but not used in the training loop
        "learning_rate": 0.05,
        "weight_momentum": 0.9,
        "weight_decay": 0.001,
        "min_learning_rate": 0.0001,
        "sched_type": "cosine_anneal", # e.g., "cosine_anneal", "cosine_anneal_wr", "none"
        "first_cycle_steps": 3,    # Relevant for "cosine_anneal_wr"
        "cycle_mult": 1.0,         # Relevant for "cosine_anneal_wr"
        "warmup_steps": 0,         # Relevant for "cosine_anneal_wr"
        "gamma": 1.0,              # Relevant for "cosine_anneal_wr"
        "max_scales": 3,
        "data_dir_on_drive": "/content/drive/MyDrive/Colab_Datasets/CIFAR10_data/",
        "base_output_dir_on_drive": "/content/drive/MyDrive/paper4/pooling/",
        "workers": 0,
        "save_checkpoints": True,
        "checkpoint_freq": 5,  # Save at the beginning of every 10th epoch (e.g., epoch 0, 10, 20...)
    }

# %% [markdown]
# Main

# %%
# Block 2: Main Runner Function (Modified)
# To be run after Block 1 definitions (provided in the previous response)

def main_runner():
    # --- Mount Google Drive (Important: Run this cell in Colab if not already done) ---
    try:
        from google.colab import drive
        drive.mount('/content/drive', force_remount=True)
        print("Google Drive mounted successfully.")
        google_drive_mounted = True
    except ModuleNotFoundError:
        print("Skipping Google Drive mount (not in Colab environment or google.colab not found). Outputs will be local.")
        google_drive_mounted = False
    except Exception as e:
        print(f"Error mounting Google Drive: {e}. Outputs will be local.")
        google_drive_mounted = False


    config["test_name_folder"] = f"test_{config['test_number']}"

    print('Single Model Random Path Training (Validations Removed from Training Loop)')
    print(f'Test Number: {config["test_number"]}')
    print('-------------------------------------------')
    print("Run Configuration:")
    for key, value in config.items():
        print(f"  {key}: {value}")
    print('-------------------------------------------')

    startTime = datetime.now()
    torch.manual_seed(config["seed"])
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(config["seed"])
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False # For reproducibility
        print("CUDA is available. Training on GPU.")
    else:
        print("CUDA not available. Training on CPU.")
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    channels = string_to_list(config["channels_string"], config["leng"])

    # --- Define Save Directory ---
    if google_drive_mounted:
        save_dir_base = os.path.join(config["base_output_dir_on_drive"], config["test_name_folder"])
        dataset_download_dir = config["data_dir_on_drive"]
    else:
        print("Warning: Google Drive not mounted. Using local session storage for outputs and datasets.")
        print("Data will be lost when the session ends if not downloaded.")
        save_dir_base = os.path.join('.', 'local_checkpoint', config["test_name_folder"])
        dataset_download_dir = "./data/"

    if not os.path.exists(save_dir_base):
        os.makedirs(save_dir_base, exist_ok=True)
    print(f"Outputs will be saved to: {os.path.abspath(save_dir_base)}")

    if not os.path.exists(dataset_download_dir):
        os.makedirs(dataset_download_dir, exist_ok=True)
    print(f"Dataset directory created/checked: {dataset_download_dir}")

    final_model_checkpoint_path = os.path.join(save_dir_base, 'model_checkpoint_final.pt')

    print(f'Creating model...')
    # Assuming CIFAR10, so num_classes=10. Adjust if your dataset differs.
    model = create_single_model(config["leng"], channels, num_classes=10).to(device)

    print('Creating optimizer and scheduler...')
    optimizer, scheduler = create_optimizer_and_scheduler(
        config["sched_type"], model,
        config["learning_rate"], config["weight_momentum"], config["weight_decay"],
        config["epochs"], config["min_learning_rate"],
        config["first_cycle_steps"], config["cycle_mult"],
        config["warmup_steps"], config["gamma"]
    )

    criterion = nn.CrossEntropyLoss().to(device)

    print(f"Loading data ({config['dataset']}) from/to {dataset_download_dir}...")
    # Validation loader is created if validation_percent > 0, but not used in this modified training loop
    train_loader, _unused_validation_loader, data_split_indices = get_data_loaders(
        config["dataset"], config["validation_percent"], config["batchsize"],
        dataset_dir=dataset_download_dir, workers=config["workers"]
    )

    print("Creating search space...")
    all_paths, num_paths = create_search_space(config["leng"], config["max_scales"])
    if num_paths == 0:
        print("CRITICAL WARNING: No paths generated by create_search_space. Path-based training will be skipped.")
    uniform_path_weights = init_path_logit(num_paths, initial_logits=1.0).to(device)

    # Lists to record training metrics throughout all epochs
    train_losses, train_accuracies = [], []

    print(f"\nStarting training for {config['epochs']} epochs on {device}...")
    for epoch_idx in range(config['epochs']):  # 0-indexed
        current_epoch_display = epoch_idx + 1  # 1-indexed for display and filenames

        # --- Save checkpoint at the beginning of each n-th training epoch ---
        if config["save_checkpoints"] and (epoch_idx % config["checkpoint_freq"] == 0):
            checkpoint_filename = f'model_checkpoint_epoch_{current_epoch_display}_begin.pt'
            checkpoint_path = os.path.join(save_dir_base, checkpoint_filename)
            print(f'Saving model checkpoint at BEGINNING of epoch {current_epoch_display} to {checkpoint_path}...')
            state = {
                'epoch_about_to_start': current_epoch_display,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'scheduler_state_dict': scheduler.state_dict() if scheduler else None,
                'train_losses': list(train_losses),  # Training metrics up to the end of the previous epoch
                'train_accuracies': list(train_accuracies),
                'config_snapshot': config,
                'data_split_indices': data_split_indices
            }
            torch.save(state, checkpoint_path)

        print(f'\nEpoch {current_epoch_display}/{config["epochs"]}')

        # --- Training Phase ---
        if num_paths > 0: # Proceed with training only if paths exist
            print(f'  Starting training phase for epoch {current_epoch_display}...')
            if optimizer.param_groups:
                print(f'  Learning rate: {optimizer.param_groups[0]["lr"]:.6f}')

            avg_loss, accuracy = train_epoch_random_paths(
                model, train_loader, optimizer, criterion, all_paths, uniform_path_weights, device
            )
            train_losses.append(avg_loss)
            train_accuracies.append(accuracy)
        else:
            print(f"  Skipping path-based training for epoch {current_epoch_display} as num_paths is 0.")
            # Append placeholder values if you want lists to have config['epochs'] length
            train_losses.append(float('nan')) # Not a Number, indicates skipped or undefined
            train_accuracies.append(float('nan'))

        if scheduler:
            scheduler.step()

    # --- Save final checkpoint after all training epochs are completed ---
    if config["save_checkpoints"]:
        print(f'Saving final model checkpoint after {config["epochs"]} epochs to {final_model_checkpoint_path}...')
        state = {
            'completed_epochs': config['epochs'],
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'scheduler_state_dict': scheduler.state_dict() if scheduler else None,
            'train_losses': train_losses, # Complete history
            'train_accuracies': train_accuracies, # Complete history
            'config_snapshot': config,
            'data_split_indices': data_split_indices
        }
        torch.save(state, final_model_checkpoint_path)

    print('-------------------------------------------')
    print('Finished Training.')
    print(f'Total execution time: {datetime.now() - startTime}')
    print(f"Results and checkpoints saved in: {os.path.abspath(save_dir_base)}")

if __name__ == '__main__':
    # This assumes Block 1 (all function and class definitions) is in the same file or has been imported.
    main_runner()
# Out:
# Mounted at /content/drive
# Google Drive mounted successfully.
# Single Model Random Path Training (Validations Removed from Training Loop)
# Test Number: 3002
# -------------------------------------------
# Run Configuration:
#   dataset: CIFAR10
#   channels_string: 16,16,16,16,32,32,32,64,64,64
#   leng: 10
#   batchsize: 512
#   test_number: 3002
#   seed: 3457
#   epochs: 200
#   validation_percent: 0.5
#   learning_rate: 0.05
#   weight_momentum: 0.9
#   weight_decay: 0.001
#   min_learning_rate: 0.0001
#   sched_type: cosine_anneal
#   first_cycle_steps: 3
#   cycle_mult: 1.0
#   warmup_steps: 0
#   gamma: 1.0
#   max_scales: 3
#   data_dir_on_drive: /content/drive/MyDrive/Colab_Datasets/CIFAR10_data/
#   base_output_dir_on_drive: /content/drive/MyDrive/paper4/pooling/
#   workers: 0
#   save_checkpoints: True
#   checkpoint_freq: 5
#   test_name_folder: test_3002
# -------------------------------------------
# CUDA is available. Training on GPU.
# Outputs will be saved to: /content/drive/MyDrive/paper4/pooling/test_3002
# Dataset directory created/checked: /content/drive/MyDrive/Colab_Datasets/CIFAR10_data/
# Creating model...
# Creating optimizer and scheduler...
# Loading data (CIFAR10) from/to /content/drive/MyDrive/Colab_Datasets/CIFAR10_data/...
# Total original training samples: 50000
# New training size: 25000, Validation size: 25000
# Creating search space...
# All 36 paths created.
#
# Starting training for 200 epochs on cuda...
# Saving model checkpoint at BEGINNING of epoch 1 to /content/drive/MyDrive/paper4/pooling/test_3002/model_checkpoint_epoch_1_begin.pt...
#
# Epoch 1/200
#   Starting training phase for epoch 1...
#   Learning rate: 0.050000
# Training Epoch: Avg Loss: 1.8948, Accuracy: 6938/24576 (28.23%)
#
# Epoch 2/200
#   Starting training phase for epoch 2...
#   Learning rate: 0.049997
# Training Epoch: Avg Loss: 1.6250, Accuracy: 9536/24576 (38.80%)
#
# Epoch 3/200
#   Starting training phase for epoch 3...
#   Learning rate: 0.049988
# Training Epoch: Avg Loss: 1.4447, Accuracy: 11489/24576 (46.75%)
#
# Epoch 4/200
#   Starting training phase for epoch 4...
#   Learning rate: 0.049972
# Training Epoch: Avg Loss: 1.3197, Accuracy: 12752/24576 (51.89%)
#
# Epoch 5/200
#   Starting training phase for epoch 5...
#   Learning rate: 0.049951
# Training Epoch: Avg Loss: 1.2413, Accuracy: 13584/24576 (55.27%)
# Saving model checkpoint at BEGINNING of epoch 6 to /content/drive/MyDrive/paper4/pooling/test_3002/model_checkpoint_epoch_6_begin.pt...
#
# Epoch 6/200
#   Starting training phase for epoch 6...
#   Learning rate: 0.049923
# Training Epoch: Avg Loss: 1.2022, Accuracy: 13883/24576 (56.49%)
#
# Epoch 7/200
#   Starting training phase for epoch 7...
#   Learning rate: 0.049889
# Training Epoch: Avg Loss: 1.1100, Accuracy: 14738/24576 (59.97%)
#
# Epoch 8/200
#   Starting training phase for epoch 8...
#   Learning rate: 0.049849
# Training Epoch: Avg Loss: 1.0539, Accuracy: 15259/24576 (62.09%)
#
# Epoch 9/200
#   Starting training phase for epoch 9...
#   Learning rate: 0.049803
# Training Epoch: Avg Loss: 1.0129, Accuracy: 15637/24576 (63.63%)
#
# Epoch 10/200
#   Starting training phase for epoch 10...
#   Learning rate: 0.049751
# Training Epoch: Avg Loss: 0.9756, Accuracy: 16001/24576 (65.11%)
# Saving model checkpoint at BEGINNING of epoch 11 to /content/drive/MyDrive/paper4/pooling/test_3002/model_checkpoint_epoch_11_begin.pt...
#
# Epoch 11/200
#   Starting training phase for epoch 11...
#   Learning rate: 0.049693
# Training Epoch: Avg Loss: 0.9345, Accuracy: 16432/24576 (66.86%)
#
# Epoch 12/200
#   Starting training phase for epoch 12...
#   Learning rate: 0.049628
# Training Epoch: Avg Loss: 0.9527, Accuracy: 16239/24576 (66.08%)
#
# Epoch 13/200
#   Starting training phase for epoch 13...
#   Learning rate: 0.049558
# Training Epoch: Avg Loss: 0.8938, Accuracy: 16769/24576 (68.23%)
#
# Epoch 14/200
#   Starting training phase for epoch 14...
#   Learning rate: 0.049482
# Training Epoch: Avg Loss: 0.8416, Accuracy: 17247/24576 (70.18%)
#
# Epoch 15/200
#   Starting training phase for epoch 15...
#   Learning rate: 0.049399
# Training Epoch: Avg Loss: 0.8548, Accuracy: 17206/24576 (70.01%)
# Saving model checkpoint at BEGINNING of epoch 16 to /content/drive/MyDrive/paper4/pooling/test_3002/model_checkpoint_epoch_16_begin.pt...
#
# Epoch 16/200
#   Starting training phase for epoch 16...
#   Learning rate: 0.049311
# Training Epoch: Avg Loss: 0.8052, Accuracy: 17647/24576 (71.81%)
#
# Epoch 17/200
#   Starting training phase for epoch 17...
#   Learning rate: 0.049216
# Training Epoch: Avg Loss: 0.7899, Accuracy: 17797/24576 (72.42%)
#
# Epoch 18/200
#   Starting training phase for epoch 18...
#   Learning rate: 0.049116
# Training Epoch: Avg Loss: 0.7981, Accuracy: 17715/24576 (72.08%)
#
# Epoch 19/200
#   Starting training phase for epoch 19...
#   Learning rate: 0.049009
# Training Epoch: Avg Loss: 0.7765, Accuracy: 17938/24576 (72.99%)
#
# Epoch 20/200
#   Starting training phase for epoch 20...
#   Learning rate: 0.048897
# Training Epoch: Avg Loss: 0.7724, Accuracy: 17866/24576 (72.70%)
# Saving model checkpoint at BEGINNING of epoch 21 to /content/drive/MyDrive/paper4/pooling/test_3002/model_checkpoint_epoch_21_begin.pt...
#
# Epoch 21/200
#   Starting training phase for epoch 21...
#   Learning rate: 0.048779
# Training Epoch: Avg Loss: 0.7224, Accuracy: 18329/24576 (74.58%)
#
# Epoch 22/200
#   Starting training phase for epoch 22...
#   Learning rate: 0.048655
# Training Epoch: Avg Loss: 0.6990, Accuracy: 18550/24576 (75.48%)
#
# Epoch 23/200
#   Starting training phase for epoch 23...
#   Learning rate: 0.048525
# Training Epoch: Avg Loss: 0.6886, Accuracy: 18593/24576 (75.66%)
#
# Epoch 24/200
#   Starting training phase for epoch 24...
#   Learning rate: 0.048389
# Training Epoch: Avg Loss: 0.6863, Accuracy: 18664/24576 (75.94%)
#
# Epoch 25/200
#   Starting training phase for epoch 25...
#   Learning rate: 0.048248
# Training Epoch: Avg Loss: 0.6976, Accuracy: 18557/24576 (75.51%)
# Saving model checkpoint at BEGINNING of epoch 26 to /content/drive/MyDrive/paper4/pooling/test_3002/model_checkpoint_epoch_26_begin.pt...
#
# Epoch 26/200
#   Starting training phase for epoch 26...
#   Learning rate: 0.048101
# Training Epoch: Avg Loss: 0.6548, Accuracy: 18926/24576 (77.01%)
#
# Epoch 27/200
#   Starting training phase for epoch 27...
#   Learning rate: 0.047948
# Training Epoch: Avg Loss: 0.6356, Accuracy: 19128/24576 (77.83%)
#
# Epoch 28/200
#   Starting training phase for epoch 28...
#   Learning rate: 0.047790
# Training Epoch: Avg Loss: 0.6743, Accuracy: 18825/24576 (76.60%)
#
# Epoch 29/200
#   Starting training phase for epoch 29...
#   Learning rate: 0.047625
# Training Epoch: Avg Loss: 0.6367, Accuracy: 19109/24576 (77.75%)
#
# Epoch 30/200
#   Starting training phase for epoch 30...
#   Learning rate: 0.047456
# Training Epoch: Avg Loss: 0.6382, Accuracy: 19196/24576 (78.11%)
# Saving model checkpoint at BEGINNING of epoch 31 to /content/drive/MyDrive/paper4/pooling/test_3002/model_checkpoint_epoch_31_begin.pt...
#
# Epoch 31/200
#   Starting training phase for epoch 31...
#   Learning rate: 0.047281
# Training Epoch: Avg Loss: 0.6070, Accuracy: 19382/24576 (78.87%)
#
# Epoch 32/200
#   Starting training phase for epoch 32...
#   Learning rate: 0.047100
# Training Epoch: Avg Loss: 0.6335, Accuracy: 19186/24576 (78.07%)
#
# Epoch 33/200
#   Starting training phase for epoch 33...
#   Learning rate: 0.046914
# Training Epoch: Avg Loss: 0.6292, Accuracy: 19169/24576 (78.00%)
#
# Epoch 34/200
#   Starting training phase for epoch 34...
#   Learning rate: 0.046722
# Training Epoch: Avg Loss: 0.6082, Accuracy: 19357/24576 (78.76%)
#
# Epoch 35/200
#   Starting training phase for epoch 35...
#   Learning rate: 0.046526
# Training Epoch: Avg Loss: 0.6193, Accuracy: 19307/24576 (78.56%)
# Saving model checkpoint at BEGINNING of epoch 36 to /content/drive/MyDrive/paper4/pooling/test_3002/model_checkpoint_epoch_36_begin.pt...
#
# Epoch 36/200
#   Starting training phase for epoch 36...
#   Learning rate: 0.046323
# Training Epoch: Avg Loss: 0.6084, Accuracy: 19334/24576 (78.67%)
#
# Epoch 37/200
#   Starting training phase for epoch 37...
#   Learning rate: 0.046116
# Training Epoch: Avg Loss: 0.5608, Accuracy: 19750/24576 (80.36%)
#
# Epoch 38/200
#   Starting training phase for epoch 38...
#   Learning rate: 0.045903
# Training Epoch: Avg Loss: 0.5998, Accuracy: 19427/24576 (79.05%)
#
# Epoch 39/200
#   Starting training phase for epoch 39...
#   Learning rate: 0.045686
# Training Epoch: Avg Loss: 0.5849, Accuracy: 19614/24576 (79.81%)
#
# Epoch 40/200
#   Starting training phase for epoch 40...
#   Learning rate: 0.045463
# Training Epoch: Avg Loss: 0.5492, Accuracy: 19891/24576 (80.94%)
# Saving model checkpoint at BEGINNING of epoch 41 to /content/drive/MyDrive/paper4/pooling/test_3002/model_checkpoint_epoch_41_begin.pt...
#
# Epoch 41/200
#   Starting training phase for epoch 41...
#   Learning rate: 0.045235
# Training Epoch: Avg Loss: 0.5805, Accuracy: 19642/24576 (79.92%)
#
# Epoch 42/200
#   Starting training phase for epoch 42...
#   Learning rate: 0.045002
# Training Epoch: Avg Loss: 0.5826, Accuracy: 19524/24576 (79.44%)
#
# Epoch 43/200
#   Starting training phase for epoch 43...
#   Learning rate: 0.044764
# Training Epoch: Avg Loss: 0.5515, Accuracy: 19909/24576 (81.01%)
#
# Epoch 44/200
#   Starting training phase for epoch 44...
#   Learning rate: 0.044522
# Training Epoch: Avg Loss: 0.5702, Accuracy: 19642/24576 (79.92%)
#
# Epoch 45/200
#   Starting training phase for epoch 45...
#   Learning rate: 0.044274
# Training Epoch: Avg Loss: 0.5444, Accuracy: 19915/24576 (81.03%)
# Saving model checkpoint at BEGINNING of epoch 46 to /content/drive/MyDrive/paper4/pooling/test_3002/model_checkpoint_epoch_46_begin.pt...
#
# Epoch 46/200
#   Starting training phase for epoch 46...
#   Learning rate: 0.044022
# Training Epoch: Avg Loss: 0.5467, Accuracy: 19928/24576 (81.09%)
#
# Epoch 47/200
#   Starting training phase for epoch 47...
#   Learning rate: 0.043765
# Training Epoch: Avg Loss: 0.5401, Accuracy: 19947/24576 (81.16%)
#
# Epoch 48/200
#   Starting training phase for epoch 48...
#   Learning rate: 0.043504
# Training Epoch: Avg Loss: 0.5280, Accuracy: 20100/24576 (81.79%)
#
# Epoch 49/200
#   Starting training phase for epoch 49...
#   Learning rate: 0.043238
# Training Epoch: Avg Loss: 0.5445, Accuracy: 19883/24576 (80.90%)
#
# Epoch 50/200
#   Starting training phase for epoch 50...
#   Learning rate: 0.042967
# Training Epoch: Avg Loss: 0.5133, Accuracy: 20226/24576 (82.30%)
# Saving model checkpoint at BEGINNING of epoch 51 to /content/drive/MyDrive/paper4/pooling/test_3002/model_checkpoint_epoch_51_begin.pt...
#
# Epoch 51/200
#   Starting training phase for epoch 51...
#   Learning rate: 0.042692
# Training Epoch: Avg Loss: 0.5216, Accuracy: 20119/24576 (81.86%)
#
# Epoch 52/200
#   Starting training phase for epoch 52...
#   Learning rate: 0.042413
# Training Epoch: Avg Loss: 0.4977, Accuracy: 20357/24576 (82.83%)
#
# Epoch 53/200
#   Starting training phase for epoch 53...
#   Learning rate: 0.042129
# Training Epoch: Avg Loss: 0.4977, Accuracy: 20351/24576 (82.81%)
#
# Epoch 54/200
#   Starting training phase for epoch 54...
#   Learning rate: 0.041842
# Training Epoch: Avg Loss: 0.5265, Accuracy: 20004/24576 (81.40%)
#
# Epoch 55/200
#   Starting training phase for epoch 55...
#   Learning rate: 0.041550
# Training Epoch: Avg Loss: 0.5158, Accuracy: 20153/24576 (82.00%)
# Saving model checkpoint at BEGINNING of epoch 56 to /content/drive/MyDrive/paper4/pooling/test_3002/model_checkpoint_epoch_56_begin.pt...
#
# Epoch 56/200
#   Starting training phase for epoch 56...
#   Learning rate: 0.041254
# Training Epoch: Avg Loss: 0.4858, Accuracy: 20397/24576 (83.00%)
#
# Epoch 57/200
#   Starting training phase for epoch 57...
#   Learning rate: 0.040954
# Training Epoch: Avg Loss: 0.5124, Accuracy: 20131/24576 (81.91%)
#
# Epoch 58/200
#   Starting training phase for epoch 58...
#   Learning rate: 0.040650
# Training Epoch: Avg Loss: 0.4940, Accuracy: 20392/24576 (82.98%)
#
# Epoch 59/200
#   Starting training phase for epoch 59...
#   Learning rate: 0.040342
# Training Epoch: Avg Loss: 0.4875, Accuracy: 20441/24576 (83.17%)
#
# Epoch 60/200
#   Starting training phase for epoch 60...
#   Learning rate: 0.040030
# Training Epoch: Avg Loss: 0.4721, Accuracy: 20581/24576 (83.74%)
# Saving model checkpoint at BEGINNING of epoch 61 to /content/drive/MyDrive/paper4/pooling/test_3002/model_checkpoint_epoch_61_begin.pt...
#
# Epoch 61/200
#   Starting training phase for epoch 61...
#   Learning rate: 0.039715
# Training Epoch: Avg Loss: 0.4757, Accuracy: 20473/24576 (83.30%)
#
# Epoch 62/200
#   Starting training phase for epoch 62...
#   Learning rate: 0.039396
# Training Epoch: Avg Loss: 0.4740, Accuracy: 20542/24576 (83.59%)
#
# Epoch 63/200
#   Starting training phase for epoch 63...
#   Learning rate: 0.039074
# Training Epoch: Avg Loss: 0.4639, Accuracy: 20609/24576 (83.86%)
#
# Epoch 64/200
#   Starting training phase for epoch 64...
#   Learning rate: 0.038748
# Training Epoch: Avg Loss: 0.4646, Accuracy: 20567/24576 (83.69%)
#
# Epoch 65/200
#   Starting training phase for epoch 65...
#   Learning rate: 0.038419
# Training Epoch: Avg Loss: 0.4830, Accuracy: 20448/24576 (83.20%)
# Saving model checkpoint at BEGINNING of epoch 66 to /content/drive/MyDrive/paper4/pooling/test_3002/model_checkpoint_epoch_66_begin.pt...
#
# Epoch 66/200
#   Starting training phase for epoch 66...
#   Learning rate: 0.038086
# Training Epoch: Avg Loss: 0.4591, Accuracy: 20666/24576 (84.09%)
#
# Epoch 67/200
#   Starting training phase for epoch 67...
#   Learning rate: 0.037751
# Training Epoch: Avg Loss: 0.4487, Accuracy: 20783/24576 (84.57%)
#
# Epoch 68/200
#   Starting training phase for epoch 68...
#   Learning rate: 0.037412
# Training Epoch: Avg Loss: 0.4726, Accuracy: 20507/24576 (83.44%)
#
# Epoch 69/200
#   Starting training phase for epoch 69...
#   Learning rate: 0.037070
# Training Epoch: Avg Loss: 0.4545, Accuracy: 20674/24576 (84.12%)
#
# Epoch 70/200
#   Starting training phase for epoch 70...
#   Learning rate: 0.036725
# Training Epoch: Avg Loss: 0.4487, Accuracy: 20751/24576 (84.44%)
# Saving model checkpoint at BEGINNING of epoch 71 to /content/drive/MyDrive/paper4/pooling/test_3002/model_checkpoint_epoch_71_begin.pt...
#
# Epoch 71/200
#   Starting training phase for epoch 71...
#   Learning rate: 0.036377
# Training Epoch: Avg Loss: 0.4829, Accuracy: 20459/24576 (83.25%)
#
# Epoch 72/200
#   Starting training phase for epoch 72...
#   Learning rate: 0.036026
# Training Epoch: Avg Loss: 0.4480, Accuracy: 20762/24576 (84.48%)
#
# Epoch 73/200
#   Starting training phase for epoch 73...
#   Learning rate: 0.035673
# Training Epoch: Avg Loss: 0.4559, Accuracy: 20626/24576 (83.93%)
#
# Epoch 74/200
#   Starting training phase for epoch 74...
#   Learning rate: 0.035317
# Training Epoch: Avg Loss: 0.4460, Accuracy: 20830/24576 (84.76%)
#
# Epoch 75/200
#   Starting training phase for epoch 75...
#   Learning rate: 0.034959
# Training Epoch: Avg Loss: 0.4518, Accuracy: 20689/24576 (84.18%)
# Saving model checkpoint at BEGINNING of epoch 76 to /content/drive/MyDrive/paper4/pooling/test_3002/model_checkpoint_epoch_76_begin.pt...
#
# Epoch 76/200
#   Starting training phase for epoch 76...
#   Learning rate: 0.034598
# Training Epoch: Avg Loss: 0.4377, Accuracy: 20825/24576 (84.74%)
#
# Epoch 77/200
#   Starting training phase for epoch 77...
#   Learning rate: 0.034235
# Training Epoch: Avg Loss: 0.4509, Accuracy: 20764/24576 (84.49%)
#
# Epoch 78/200
#   Starting training phase for epoch 78...
#   Learning rate: 0.033869
# Training Epoch: Avg Loss: 0.4136, Accuracy: 20997/24576 (85.44%)
#
# Epoch 79/200
#   Starting training phase for epoch 79...
#   Learning rate: 0.033502
# Training Epoch: Avg Loss: 0.4246, Accuracy: 20927/24576 (85.15%)
#
# Epoch 80/200
#   Starting training phase for epoch 80...
#   Learning rate: 0.033132
# Training Epoch: Avg Loss: 0.4349, Accuracy: 20859/24576 (84.88%)
# Saving model checkpoint at BEGINNING of epoch 81 to /content/drive/MyDrive/paper4/pooling/test_3002/model_checkpoint_epoch_81_begin.pt...
#
# Epoch 81/200
#   Starting training phase for epoch 81...
#   Learning rate: 0.032760
# Training Epoch: Avg Loss: 0.4397, Accuracy: 20805/24576 (84.66%)
#
# Epoch 82/200
#   Starting training phase for epoch 82...
#   Learning rate: 0.032386
# Training Epoch: Avg Loss: 0.4287, Accuracy: 20887/24576 (84.99%)
#
# Epoch 83/200
#   Starting training phase for epoch 83...
#   Learning rate: 0.032011
# Training Epoch: Avg Loss: 0.4269, Accuracy: 20862/24576 (84.89%)
#
# Epoch 84/200
#   Starting training phase for epoch 84...
#   Learning rate: 0.031634
# Training Epoch: Avg Loss: 0.4377, Accuracy: 20834/24576 (84.77%)
#
# Epoch 85/200
#   Starting training phase for epoch 85...
#   Learning rate: 0.031255
# Training Epoch: Avg Loss: 0.4042, Accuracy: 21129/24576 (85.97%)
# Saving model checkpoint at BEGINNING of epoch 86 to /content/drive/MyDrive/paper4/pooling/test_3002/model_checkpoint_epoch_86_begin.pt...
#
# Epoch 86/200
#   Starting training phase for epoch 86...
#   Learning rate: 0.030874
# Training Epoch: Avg Loss: 0.4374, Accuracy: 20816/24576 (84.70%)
#
# Epoch 87/200
#   Starting training phase for epoch 87...
#   Learning rate: 0.030493
# Training Epoch: Avg Loss: 0.4274, Accuracy: 20953/24576 (85.26%)
#
# Epoch 88/200
#   Starting training phase for epoch 88...
#   Learning rate: 0.030110
# Training Epoch: Avg Loss: 0.3918, Accuracy: 21225/24576 (86.36%)
#
# Epoch 89/200
#   Starting training phase for epoch 89...
#   Learning rate: 0.029725
# Training Epoch: Avg Loss: 0.3991, Accuracy: 21175/24576 (86.16%)
#
# Epoch 90/200
#   Starting training phase for epoch 90...
#   Learning rate: 0.029340
# Training Epoch: Avg Loss: 0.4043, Accuracy: 21102/24576 (85.86%)
# Saving model checkpoint at BEGINNING of epoch 91 to /content/drive/MyDrive/paper4/pooling/test_3002/model_checkpoint_epoch_91_begin.pt...
#
# Epoch 91/200
#   Starting training phase for epoch 91...
#   Learning rate: 0.028953
# Training Epoch: Avg Loss: 0.3923, Accuracy: 21210/24576 (86.30%)
#
# Epoch 92/200
#   Starting training phase for epoch 92...
#   Learning rate: 0.028565
# Training Epoch: Avg Loss: 0.3758, Accuracy: 21375/24576 (86.98%)
#
# Epoch 93/200
#   Starting training phase for epoch 93...
#   Learning rate: 0.028177
# Training Epoch: Avg Loss: 0.3895, Accuracy: 21268/24576 (86.54%)
#
# Epoch 94/200
#   Starting training phase for epoch 94...
#   Learning rate: 0.027788
# Training Epoch: Avg Loss: 0.4054, Accuracy: 21098/24576 (85.85%)
#
# Epoch 95/200
#   Starting training phase for epoch 95...
#   Learning rate: 0.027398
# Training Epoch: Avg Loss: 0.3905, Accuracy: 21183/24576 (86.19%)
# Saving model checkpoint at BEGINNING of epoch 96 to /content/drive/MyDrive/paper4/pooling/test_3002/model_checkpoint_epoch_96_begin.pt...
#
# Epoch 96/200
#   Starting training phase for epoch 96...
#   Learning rate: 0.027008
# Training Epoch: Avg Loss: 0.3806, Accuracy: 21323/24576 (86.76%)
#
# Epoch 97/200
#   Starting training phase for epoch 97...
#   Learning rate: 0.026617
# Training Epoch: Avg Loss: 0.3788, Accuracy: 21310/24576 (86.71%)
#
# Epoch 98/200
#   Starting training phase for epoch 98...
#   Learning rate: 0.026225
# Training Epoch: Avg Loss: 0.3666, Accuracy: 21440/24576 (87.24%)
#
# Epoch 99/200
#   Starting training phase for epoch 99...
#   Learning rate: 0.025834
# Training Epoch: Avg Loss: 0.3544, Accuracy: 21527/24576 (87.59%)
#
# Epoch 100/200
#   Starting training phase for epoch 100...
#   Learning rate: 0.025442
# Training Epoch: Avg Loss: 0.3629, Accuracy: 21450/24576 (87.28%)
# Saving model checkpoint at BEGINNING of epoch 101 to /content/drive/MyDrive/paper4/pooling/test_3002/model_checkpoint_epoch_101_begin.pt...
#
# Epoch 101/200
#   Starting training phase for epoch 101...
#   Learning rate: 0.025050
# Training Epoch: Avg Loss: 0.3711, Accuracy: 21424/24576 (87.17%)
#
# Epoch 102/200
#   Starting training phase for epoch 102...
#   Learning rate: 0.024658
# Training Epoch: Avg Loss: 0.3691, Accuracy: 21381/24576 (87.00%)
#
# Epoch 103/200
#   Starting training phase for epoch 103...
#   Learning rate: 0.024266
# Training Epoch: Avg Loss: 0.3620, Accuracy: 21499/24576 (87.48%)
#
# Epoch 104/200
#   Starting training phase for epoch 104...
#   Learning rate: 0.023875
# Training Epoch: Avg Loss: 0.3475, Accuracy: 21601/24576 (87.89%)
#
# Epoch 105/200
#   Starting training phase for epoch 105...
#   Learning rate: 0.023483
# Training Epoch: Avg Loss: 0.3582, Accuracy: 21470/24576 (87.36%)
# Saving model checkpoint at BEGINNING of epoch 106 to /content/drive/MyDrive/paper4/pooling/test_3002/model_checkpoint_epoch_106_begin.pt...
#
# Epoch 106/200
#   Starting training phase for epoch 106...
#   Learning rate: 0.023092
# Training Epoch: Avg Loss: 0.3545, Accuracy: 21549/24576 (87.68%)
#
# Epoch 107/200
#   Starting training phase for epoch 107...
#   Learning rate: 0.022702
# Training Epoch: Avg Loss: 0.3491, Accuracy: 21597/24576 (87.88%)
#
# Epoch 108/200
#   Starting training phase for epoch 108...
#   Learning rate: 0.022312
# Training Epoch: Avg Loss: 0.3460, Accuracy: 21559/24576 (87.72%)
#
# Epoch 109/200
#   Starting training phase for epoch 109...
#   Learning rate: 0.021923
# Training Epoch: Avg Loss: 0.3366, Accuracy: 21646/24576 (88.08%)
#
# Epoch 110/200
#   Starting training phase for epoch 110...
#   Learning rate: 0.021535
# Training Epoch: Avg Loss: 0.3571, Accuracy: 21536/24576 (87.63%)
# Saving model checkpoint at BEGINNING of epoch 111 to /content/drive/MyDrive/paper4/pooling/test_3002/model_checkpoint_epoch_111_begin.pt...
#
# Epoch 111/200
#   Starting training phase for epoch 111...
#   Learning rate: 0.021147
# Training Epoch: Avg Loss: 0.3227, Accuracy: 21783/24576 (88.64%)
#
# Epoch 112/200
#   Starting training phase for epoch 112...
#   Learning rate: 0.020760
# Training Epoch: Avg Loss: 0.3416, Accuracy: 21590/24576 (87.85%)
#
# Epoch 113/200
#   Starting training phase for epoch 113...
#   Learning rate: 0.020375
# Training Epoch: Avg Loss: 0.3363, Accuracy: 21693/24576 (88.27%)
#
# Epoch 114/200
#   Starting training phase for epoch 114...
#   Learning rate: 0.019990
# Training Epoch: Avg Loss: 0.3401, Accuracy: 21617/24576 (87.96%)
#
# Epoch 115/200
#   Starting training phase for epoch 115...
#   Learning rate: 0.019607
# Training Epoch: Avg Loss: 0.3246, Accuracy: 21737/24576 (88.45%)
# Saving model checkpoint at BEGINNING of epoch 116 to /content/drive/MyDrive/paper4/pooling/test_3002/model_checkpoint_epoch_116_begin.pt...
#
# Epoch 116/200
#   Starting training phase for epoch 116...
#   Learning rate: 0.019226
# Training Epoch: Avg Loss: 0.3368, Accuracy: 21653/24576 (88.11%)
#
# Epoch 117/200
#   Starting training phase for epoch 117...
#   Learning rate: 0.018845
# Training Epoch: Avg Loss: 0.3336, Accuracy: 21689/24576 (88.25%)
#
# Epoch 118/200
#   Starting training phase for epoch 118...
#   Learning rate: 0.018466
# Training Epoch: Avg Loss: 0.3162, Accuracy: 21915/24576 (89.17%)
#
# Epoch 119/200
#   Starting training phase for epoch 119...
#   Learning rate: 0.018089
# Training Epoch: Avg Loss: 0.2970, Accuracy: 22049/24576 (89.72%)
#
# Epoch 120/200
#   Starting training phase for epoch 120...
#   Learning rate: 0.017714
# Training Epoch: Avg Loss: 0.3122, Accuracy: 21884/24576 (89.05%)
# Saving model checkpoint at BEGINNING of epoch 121 to /content/drive/MyDrive/paper4/pooling/test_3002/model_checkpoint_epoch_121_begin.pt...
#
# Epoch 121/200
#   Starting training phase for epoch 121...
#   Learning rate: 0.017340
# Training Epoch: Avg Loss: 0.3023, Accuracy: 21993/24576 (89.49%)
#
# Epoch 122/200
#   Starting training phase for epoch 122...
#   Learning rate: 0.016968
# Training Epoch: Avg Loss: 0.3108, Accuracy: 21926/24576 (89.22%)
#
# Epoch 123/200
#   Starting training phase for epoch 123...
#   Learning rate: 0.016598
# Training Epoch: Avg Loss: 0.3099, Accuracy: 21922/24576 (89.20%)
#
# Epoch 124/200
#   Starting training phase for epoch 124...
#   Learning rate: 0.016231
# Training Epoch: Avg Loss: 0.3179, Accuracy: 21852/24576 (88.92%)
#
# Epoch 125/200
#   Starting training phase for epoch 125...
#   Learning rate: 0.015865
# Training Epoch: Avg Loss: 0.2966, Accuracy: 22051/24576 (89.73%)
# Saving model checkpoint at BEGINNING of epoch 126 to /content/drive/MyDrive/paper4/pooling/test_3002/model_checkpoint_epoch_126_begin.pt...
#
# Epoch 126/200
#   Starting training phase for epoch 126...
#   Learning rate: 0.015502
# Training Epoch: Avg Loss: 0.2932, Accuracy: 22035/24576 (89.66%)
#
# Epoch 127/200
#   Starting training phase for epoch 127...
#   Learning rate: 0.015141
# Training Epoch: Avg Loss: 0.2904, Accuracy: 22087/24576 (89.87%)
#
# Epoch 128/200
#   Starting training phase for epoch 128...
#   Learning rate: 0.014783
# Training Epoch: Avg Loss: 0.3005, Accuracy: 21974/24576 (89.41%)
#
# Epoch 129/200
#   Starting training phase for epoch 129...
#   Learning rate: 0.014427
# Training Epoch: Avg Loss: 0.2634, Accuracy: 22302/24576 (90.75%)
#
# Epoch 130/200
#   Starting training phase for epoch 130...
#   Learning rate: 0.014074
# Training Epoch: Avg Loss: 0.2635, Accuracy: 22321/24576 (90.82%)
# Saving model checkpoint at BEGINNING of epoch 131 to /content/drive/MyDrive/paper4/pooling/test_3002/model_checkpoint_epoch_131_begin.pt...
#
# Epoch 131/200
#   Starting training phase for epoch 131...
#   Learning rate: 0.013723
# Training Epoch: Avg Loss: 0.2887, Accuracy: 22096/24576 (89.91%)
#
# Epoch 132/200
#   Starting training phase for epoch 132...
#   Learning rate: 0.013375
# Training Epoch: Avg Loss: 0.2754, Accuracy: 22227/24576 (90.44%)
#
# Epoch 133/200
#   Starting training phase for epoch 133...
#   Learning rate: 0.013030
# Training Epoch: Avg Loss: 0.2895, Accuracy: 22067/24576 (89.79%)
#
# Epoch 134/200
#   Starting training phase for epoch 134...
#   Learning rate: 0.012688
# Training Epoch: Avg Loss: 0.2682, Accuracy: 22249/24576 (90.53%)
#
# Epoch 135/200
#   Starting training phase for epoch 135...
#   Learning rate: 0.012349
# Training Epoch: Avg Loss: 0.2752, Accuracy: 22202/24576 (90.34%)
# Saving model checkpoint at BEGINNING of epoch 136 to /content/drive/MyDrive/paper4/pooling/test_3002/model_checkpoint_epoch_136_begin.pt...
#
# Epoch 136/200
#   Starting training phase for epoch 136...
#   Learning rate: 0.012014
# Training Epoch: Avg Loss: 0.2540, Accuracy: 22405/24576 (91.17%)
#
# Epoch 137/200
#   Starting training phase for epoch 137...
#   Learning rate: 0.011681
# Training Epoch: Avg Loss: 0.2620, Accuracy: 22318/24576 (90.81%)
#
# Epoch 138/200
#   Starting training phase for epoch 138...
#   Learning rate: 0.011352
# Training Epoch: Avg Loss: 0.2471, Accuracy: 22466/24576 (91.41%)
#
# Epoch 139/200
#   Starting training phase for epoch 139...
#   Learning rate: 0.011026
# Training Epoch: Avg Loss: 0.2550, Accuracy: 22370/24576 (91.02%)
#
# Epoch 140/200
#   Starting training phase for epoch 140...
#   Learning rate: 0.010704
# Training Epoch: Avg Loss: 0.2540, Accuracy: 22380/24576 (91.06%)
# Saving model checkpoint at BEGINNING of epoch 141 to /content/drive/MyDrive/paper4/pooling/test_3002/model_checkpoint_epoch_141_begin.pt...
#
# Epoch 141/200
#   Starting training phase for epoch 141...
#   Learning rate: 0.010385
# Training Epoch: Avg Loss: 0.2475, Accuracy: 22467/24576 (91.42%)
#
# Epoch 142/200
#   Starting training phase for epoch 142...
#   Learning rate: 0.010070
# Training Epoch: Avg Loss: 0.2471, Accuracy: 22453/24576 (91.36%)
#
# Epoch 143/200
#   Starting training phase for epoch 143...
#   Learning rate: 0.009758
# Training Epoch: Avg Loss: 0.2429, Accuracy: 22481/24576 (91.48%)
#
# Epoch 144/200
#   Starting training phase for epoch 144...
#   Learning rate: 0.009450
# Training Epoch: Avg Loss: 0.2345, Accuracy: 22556/24576 (91.78%)
#
# Epoch 145/200
#   Starting training phase for epoch 145...
#   Learning rate: 0.009146
# Training Epoch: Avg Loss: 0.2120, Accuracy: 22729/24576 (92.48%)
# Saving model checkpoint at BEGINNING of epoch 146 to /content/drive/MyDrive/paper4/pooling/test_3002/model_checkpoint_epoch_146_begin.pt...
#
# Epoch 146/200
#   Starting training phase for epoch 146...
#   Learning rate: 0.008846
# Training Epoch: Avg Loss: 0.2306, Accuracy: 22610/24576 (92.00%)
#
# Epoch 147/200
#   Starting training phase for epoch 147...
#   Learning rate: 0.008550
# Training Epoch: Avg Loss: 0.2522, Accuracy: 22429/24576 (91.26%)
#
# Epoch 148/200
#   Starting training phase for epoch 148...
#   Learning rate: 0.008258
# Training Epoch: Avg Loss: 0.2231, Accuracy: 22684/24576 (92.30%)
#
# Epoch 149/200
#   Starting training phase for epoch 149...
#   Learning rate: 0.007971
# Training Epoch: Avg Loss: 0.2406, Accuracy: 22517/24576 (91.62%)
#
# Epoch 150/200
#   Starting training phase for epoch 150...
#   Learning rate: 0.007687
# Training Epoch: Avg Loss: 0.2296, Accuracy: 22607/24576 (91.99%)
# Saving model checkpoint at BEGINNING of epoch 151 to /content/drive/MyDrive/paper4/pooling/test_3002/model_checkpoint_epoch_151_begin.pt...
#
# Epoch 151/200
#   Starting training phase for epoch 151...
#   Learning rate: 0.007408
# Training Epoch: Avg Loss: 0.2170, Accuracy: 22743/24576 (92.54%)
#
# Epoch 152/200
#   Starting training phase for epoch 152...
#   Learning rate: 0.007133
# Training Epoch: Avg Loss: 0.2063, Accuracy: 22846/24576 (92.96%)
#
# Epoch 153/200
#   Starting training phase for epoch 153...
#   Learning rate: 0.006862
# Training Epoch: Avg Loss: 0.1958, Accuracy: 22939/24576 (93.34%)
#
# Epoch 154/200
#   Starting training phase for epoch 154...
#   Learning rate: 0.006596
# Training Epoch: Avg Loss: 0.1966, Accuracy: 22920/24576 (93.26%)
#
# Epoch 155/200
#   Starting training phase for epoch 155...
#   Learning rate: 0.006335
# Training Epoch: Avg Loss: 0.2170, Accuracy: 22762/24576 (92.62%)
# Saving model checkpoint at BEGINNING of epoch 156 to /content/drive/MyDrive/paper4/pooling/test_3002/model_checkpoint_epoch_156_begin.pt...
#
# Epoch 156/200
#   Starting training phase for epoch 156...
#   Learning rate: 0.006078
# Training Epoch: Avg Loss: 0.2022, Accuracy: 22882/24576 (93.11%)
#
# Epoch 157/200
#   Starting training phase for epoch 157...
#   Learning rate: 0.005826
# Training Epoch: Avg Loss: 0.1922, Accuracy: 22917/24576 (93.25%)
#
# Epoch 158/200
#   Starting training phase for epoch 158...
#   Learning rate: 0.005578
# Training Epoch: Avg Loss: 0.1952, Accuracy: 22910/24576 (93.22%)
#
# Epoch 159/200
#   Starting training phase for epoch 159...
#   Learning rate: 0.005336
# Training Epoch: Avg Loss: 0.2004, Accuracy: 22925/24576 (93.28%)
#
# Epoch 160/200
#   Starting training phase for epoch 160...
#   Learning rate: 0.005098
# Training Epoch: Avg Loss: 0.1984, Accuracy: 22889/24576 (93.14%)
# Saving model checkpoint at BEGINNING of epoch 161 to /content/drive/MyDrive/paper4/pooling/test_3002/model_checkpoint_epoch_161_begin.pt...
#
# Epoch 161/200
#   Starting training phase for epoch 161...
#   Learning rate: 0.004865
# Training Epoch: Avg Loss: 0.1853, Accuracy: 23023/24576 (93.68%)
#
# Epoch 162/200
#   Starting training phase for epoch 162...
#   Learning rate: 0.004637
# Training Epoch: Avg Loss: 0.1854, Accuracy: 22980/24576 (93.51%)
#
# Epoch 163/200
#   Starting training phase for epoch 163...
#   Learning rate: 0.004414
# Training Epoch: Avg Loss: 0.2104, Accuracy: 22817/24576 (92.84%)
#
# Epoch 164/200
#   Starting training phase for epoch 164...
#   Learning rate: 0.004197
# Training Epoch: Avg Loss: 0.1961, Accuracy: 22915/24576 (93.24%)
#
# Epoch 165/200
#   Starting training phase for epoch 165...
#   Learning rate: 0.003984
# Training Epoch: Avg Loss: 0.1800, Accuracy: 23058/24576 (93.82%)
# Saving model checkpoint at BEGINNING of epoch 166 to /content/drive/MyDrive/paper4/pooling/test_3002/model_checkpoint_epoch_166_begin.pt...
#
# Epoch 166/200
#   Starting training phase for epoch 166...
#   Learning rate: 0.003777
# Training Epoch: Avg Loss: 0.1833, Accuracy: 23050/24576 (93.79%)
#
# Epoch 167/200
#   Starting training phase for epoch 167...
#   Learning rate: 0.003574
# Training Epoch: Avg Loss: 0.1741, Accuracy: 23121/24576 (94.08%)
#
# Epoch 168/200
#   Starting training phase for epoch 168...
#   Learning rate: 0.003378
# Training Epoch: Avg Loss: 0.1916, Accuracy: 22958/24576 (93.42%)
#
# Epoch 169/200
#   Starting training phase for epoch 169...
#   Learning rate: 0.003186
# Training Epoch: Avg Loss: 0.1556, Accuracy: 23269/24576 (94.68%)
#
# Epoch 170/200
#   Starting training phase for epoch 170...
#   Learning rate: 0.003000
# Training Epoch: Avg Loss: 0.1733, Accuracy: 23110/24576 (94.03%)
# Saving model checkpoint at BEGINNING of epoch 171 to /content/drive/MyDrive/paper4/pooling/test_3002/model_checkpoint_epoch_171_begin.pt...
#
# Epoch 171/200
#   Starting training phase for epoch 171...
#   Learning rate: 0.002819
# Training Epoch: Avg Loss: 0.1766, Accuracy: 23055/24576 (93.81%)
#
# Epoch 172/200
#   Starting training phase for epoch 172...
#   Learning rate: 0.002644
# Training Epoch: Avg Loss: 0.1722, Accuracy: 23121/24576 (94.08%)
#
# Epoch 173/200
#   Starting training phase for epoch 173...
#   Learning rate: 0.002475
# Training Epoch: Avg Loss: 0.1692, Accuracy: 23146/24576 (94.18%)
#
# Epoch 174/200
#   Starting training phase for epoch 174...
#   Learning rate: 0.002310
# Training Epoch: Avg Loss: 0.1629, Accuracy: 23240/24576 (94.56%)
#
# Epoch 175/200
#   Starting training phase for epoch 175...
#   Learning rate: 0.002152
# Training Epoch: Avg Loss: 0.1752, Accuracy: 23108/24576 (94.03%)
# Saving model checkpoint at BEGINNING of epoch 176 to /content/drive/MyDrive/paper4/pooling/test_3002/model_checkpoint_epoch_176_begin.pt...
#
# Epoch 176/200
#   Starting training phase for epoch 176...
#   Learning rate: 0.001999
# Training Epoch: Avg Loss: 0.1723, Accuracy: 23140/24576 (94.16%)
#
# Epoch 177/200
#   Starting training phase for epoch 177...
#   Learning rate: 0.001852
# Training Epoch: Avg Loss: 0.1623, Accuracy: 23256/24576 (94.63%)
#
# Epoch 178/200
#   Starting training phase for epoch 178...
#   Learning rate: 0.001711
# Training Epoch: Avg Loss: 0.1511, Accuracy: 23341/24576 (94.97%)
#
# Epoch 179/200
#   Starting training phase for epoch 179...
#   Learning rate: 0.001575
# Training Epoch: Avg Loss: 0.1585, Accuracy: 23265/24576 (94.67%)
#
# Epoch 180/200
#   Starting training phase for epoch 180...
#   Learning rate: 0.001445
# Training Epoch: Avg Loss: 0.1641, Accuracy: 23190/24576 (94.36%)
# Saving model checkpoint at BEGINNING of epoch 181 to /content/drive/MyDrive/paper4/pooling/test_3002/model_checkpoint_epoch_181_begin.pt...
#
# Epoch 181/200
#   Starting training phase for epoch 181...
#   Learning rate: 0.001321
# Training Epoch: Avg Loss: 0.1472, Accuracy: 23379/24576 (95.13%)
#
# Epoch 182/200
#   Starting training phase for epoch 182...
#   Learning rate: 0.001203
# Training Epoch: Avg Loss: 0.1423, Accuracy: 23413/24576 (95.27%)
#
# Epoch 183/200
#   Starting training phase for epoch 183...
#   Learning rate: 0.001091
# Training Epoch: Avg Loss: 0.1429, Accuracy: 23425/24576 (95.32%)
#
# Epoch 184/200
#   Starting training phase for epoch 184...
#   Learning rate: 0.000984
# Training Epoch: Avg Loss: 0.1583, Accuracy: 23236/24576 (94.55%)
#
# Epoch 185/200
#   Starting training phase for epoch 185...
#   Learning rate: 0.000884
# Training Epoch: Avg Loss: 0.1537, Accuracy: 23301/24576 (94.81%)
# Saving model checkpoint at BEGINNING of epoch 186 to /content/drive/MyDrive/paper4/pooling/test_3002/model_checkpoint_epoch_186_begin.pt...
#
# Epoch 186/200
#   Starting training phase for epoch 186...
#   Learning rate: 0.000789
# Training Epoch: Avg Loss: 0.1424, Accuracy: 23410/24576 (95.26%)
#
# Epoch 187/200
#   Starting training phase for epoch 187...
#   Learning rate: 0.000701
# Training Epoch: Avg Loss: 0.1511, Accuracy: 23314/24576 (94.86%)
#
# Epoch 188/200
#   Starting training phase for epoch 188...
#   Learning rate: 0.000618
# Training Epoch: Avg Loss: 0.1438, Accuracy: 23416/24576 (95.28%)
#
# Epoch 189/200
#   Starting training phase for epoch 189...
#   Learning rate: 0.000542
# Training Epoch: Avg Loss: 0.1552, Accuracy: 23301/24576 (94.81%)
#
# Epoch 190/200
#   Starting training phase for epoch 190...
#   Learning rate: 0.000472
# Training Epoch: Avg Loss: 0.1530, Accuracy: 23338/24576 (94.96%)
# Saving model checkpoint at BEGINNING of epoch 191 to /content/drive/MyDrive/paper4/pooling/test_3002/model_checkpoint_epoch_191_begin.pt...
#
# Epoch 191/200
#   Starting training phase for epoch 191...
#   Learning rate: 0.000407
# Training Epoch: Avg Loss: 0.1487, Accuracy: 23346/24576 (95.00%)
#
# Epoch 192/200
#   Starting training phase for epoch 192...
#   Learning rate: 0.000349
# Training Epoch: Avg Loss: 0.1588, Accuracy: 23240/24576 (94.56%)
#
# Epoch 193/200
#   Starting training phase for epoch 193...
#   Learning rate: 0.000297
# Training Epoch: Avg Loss: 0.1446, Accuracy: 23384/24576 (95.15%)
#
# Epoch 194/200
#   Starting training phase for epoch 194...
#   Learning rate: 0.000251
# Training Epoch: Avg Loss: 0.1466, Accuracy: 23350/24576 (95.01%)
#
# Epoch 195/200
#   Starting training phase for epoch 195...
#   Learning rate: 0.000211
# Training Epoch: Avg Loss: 0.1417, Accuracy: 23417/24576 (95.28%)
# Saving model checkpoint at BEGINNING of epoch 196 to /content/drive/MyDrive/paper4/pooling/test_3002/model_checkpoint_epoch_196_begin.pt...
#
# Epoch 196/200
#   Starting training phase for epoch 196...
#   Learning rate: 0.000177
# Training Epoch: Avg Loss: 0.1405, Accuracy: 23424/24576 (95.31%)
#
# Epoch 197/200
#   Starting training phase for epoch 197...
#   Learning rate: 0.000149
# Training Epoch: Avg Loss: 0.1384, Accuracy: 23415/24576 (95.28%)
#
# Epoch 198/200
#   Starting training phase for epoch 198...
#   Learning rate: 0.000128
# Training Epoch: Avg Loss: 0.1458, Accuracy: 23397/24576 (95.20%)
#
# Epoch 199/200
#   Starting training phase for epoch 199...
#   Learning rate: 0.000112
# Training Epoch: Avg Loss: 0.1286, Accuracy: 23574/24576 (95.92%)
#
# Epoch 200/200
#   Starting training phase for epoch 200...
#   Learning rate: 0.000103
# Training Epoch: Avg Loss: 0.1328, Accuracy: 23467/24576 (95.49%)
# Saving final model checkpoint after 200 epochs to /content/drive/MyDrive/paper4/pooling/test_3002/model_checkpoint_final.pt...
# -------------------------------------------
# Finished Training.
# Total execution time: 0:38:25.401611
# Results and checkpoints saved in: /content/drive/MyDrive/paper4/pooling/test_3002
